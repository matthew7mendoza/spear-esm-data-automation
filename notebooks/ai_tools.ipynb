# %% [markdown]
# # Follow the instructions to use the tool
#
# ## 1. Upload all your files to the input folder
#
# ## 2. Activate the Agent
#
# ## 3. Select document type you are trying to fill out

# %%
import sys
import os
from pathlib import Path
from dotenv import load_dotenv

project_root = str(Path("..").resolve())
if project_root not in sys.path:
    sys.path.append(project_root)
from src.generator import generate_document_draft
load_dotenv(Path("../.env"))

API_KEY = os.environ.get("GEMINI_API_KEY")

# Options include ("DMP", "README", "DOI")
TARGET_DOCUMENT_TYPE = "README"
INPUT_DIRECTORY = Path("../inputs")

generate_document_draft(
    target_document_type=TARGET_DOCUMENT_TYPE,
    input_dir=INPUT_DIRECTORY,
    api_key=API_KEY
)
# Out:
# AI AGENT ACTIVATED
# Configuration loaded. Found 1 supported file(s):
#  -> mchugh_2023_readme_stress_test.txt
#
# --- Assembling knowledge base for README ---
# Reading: mchugh_2023_readme_stress_test.txt...
#
#  ---Processing README extraction via LLM---
# Extraction complete.
#
# ---- GENERATED README DRAFT ----
#
# 1. Title of Dataset:
# > Supporting data for McHugh et al. 2023, “Using Large Ensembles to Examine Historical and Projected Changes in Record-Breaking Summertime Temperatures over the Contiguous United States.”
#
# 2. Creators/Author list Information (author list on paper? Different order?)
# > Principal Investigator: Colleen E. McHugh; Co-authors: Thomas L. Delworth
#
# 2.A. Principal Investigator Contact Information (Name, Institution, Address, Email):
# > Name: Colleen E. McHugh, Institution: Science Applications International Corporation, Address: 201 Forrestal Road, Princeton, NJ 08540, Email: colleen.mchugh@noaa.gov
#
# ...
